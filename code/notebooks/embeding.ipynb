# %%
import os

SQL_DB_FOLDER = r"..\data\databases"
VECTOR_DB_FOLDER = r"..\data\vector_database"
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")

# %%
from code.embedding import build_movie_embeddings

stats = build_movie_embeddings(
    db_folder=SQL_DB_FOLDER,
    chroma_path=VECTOR_DB_FOLDER,
    force_rebuild=True,  # True = recrée tout
    batch_size=100        # Films par batch
)
# Out:
# ...
# 🎬 MOVIE EMBEDDING BUILDER
# ...
#
# 📥 Step 1: Extracting movies from databases...
# 📁 Scanning 1 database(s)...
#
# 📁 Database: movie.db
#   📋 Table: amazon_prime_titles - 9668 entries
#   📋 Table: disney_plus_titles - 1450 entries
#   📋 Table: netflix_titles - 8807 entries
#
# ✅ Total: 19925 movies/shows extracted
#
# 🗄️ Step 2: Initializing ChromaDB...
# ✅ Collection: movie_descriptions
#    Count: 0 embeddings
#
# 🔮 Step 3: Creating embeddings...
# 📊 Found 0 existing embeddings
#
# 🔄 Processing 19925 new movies in batches of 100...
#   ✅ Batch 1: Added 100 movies (total: 100/19925)
#   ✅ Batch 2: Added 100 movies (total: 200/19925)
#   ✅ Batch 3: Added 100 movies (total: 300/19925)
#   ✅ Batch 4: Added 100 movies (total: 400/19925)
#   ✅ Batch 5: Added 100 movies (total: 500/19925)
#   ✅ Batch 6: Added 100 movies (total: 600/19925)
#   ✅ Batch 7: Added 100 movies (total: 700/19925)
#   ✅ Batch 8: Added 100 movies (total: 800/19925)
#   ✅ Batch 9: Added 100 movies (total: 900/19925)
# ...
